# %% [markdown]
# <a href="https://colab.research.google.com/github/crescentiana/week_1_lab/blob/main/example_lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "Madina Hazratova"

# %%
my_enrollment_number = "A85205225006"

# %%
my_hobby = "Drawing, Creating graphic designs"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is Madina Hazratova, and my my enrollment number is A85205225006. I like Drawing, Creating graphic designs.
